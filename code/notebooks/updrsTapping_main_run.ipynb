# %% [markdown]
# ## UPDRS-Tapping Assessment - Execution Notebook
#
# This notebooks investigates optimal hand- and fingertapping algorithms as part of the
# ReTune-Dyskinesia project.

# %% [markdown]
# ### 0. Loading packages and functions, defining paths

# %%
# Importing Python and external packages
import os
import sys
import importlib
import json
import pandas as pd
import numpy as np
import sklearn as sk
import scipy
import matplotlib.pyplot as plt
# import matplotlib.gridspec as gridspec

import seaborn as sns
from scipy import signal
from scipy import stats
from array import array
import datetime as dt
import h5py
from dataclasses import  dataclass, field
from itertools import compress
from typing import Any

# %%
# check some package versions for documentation and reproducability
print('Python sys', sys.version)
print('pandas', pd.__version__)
print('numpy', np.__version__)
# print('mne_bids', mne_bids.__version__)
# print('mne', mne.__version__)
print('sci-py', scipy.__version__)
print('sci-kit learn', sk.__version__)
## FEB 2022:
# Python sys 3.9.7 (default, Sep 16 2021, 08:50:36) 
# [Clang 10.0.0 ]
# pandas 1.3.4
# numpy 1.20.3
# mne_bids 0.9
# mne 0.24.1
# sci-py 1.7.1
# sci-kit learn 1.0.1
# Out:
# Python sys 3.9.7 (default, Sep 16 2021, 08:50:36)
# [Clang 10.0.0 ]
# pandas 1.3.4
# numpy 1.20.3
# sci-py 1.7.1
# sci-kit learn 1.0.1

# %%
# define local storage directories
projectpath = '/Users/jeroenhabets/Research/CHARITE/projects/dyskinesia_neurophys'
codepath = os.path.join(projectpath, 'code')
pynmd_path = os.path.join(codepath, 'py_neuromodulation')
rawdatapath = '/Users/jeroenhabets/OneDrive - Charité - Universitätsmedizin Berlin/BIDS_Berlin_ECOG_LFP/rawdata'
proc_data_path = os.path.join(projectpath, 'data/preprocess')
# change working directory to project-code folder
os.chdir(projectpath)
temp_save = os.path.join(projectpath, 'figures/TEMP')
os.getcwd()
# Out:
# '/Users/jeroenhabets/Research/CHARITE/projects/dyskinesia_neurophys'

# %%
os.chdir(codepath)
# own data preprocessing functions
import lfpecog_features.updrsTapping_import as tap_import
import lfpecog_features.tapping_preprocess as tap_preproc
import lfpecog_features.tapping_find_blocks as find_blocks
import lfpecog_features.tapping_impact_finder as tap_impact
import lfpecog_features.tapping_run as tap_run
import lfpecog_features.tapping_time_detect as tap_times

# ft extraction
import lfpecog_features.tapping_featureset as tap_fts_set
import lfpecog_features.tapping_extract_features as tap_ft_extr
import lfpecog_features.tapping_feat_calc as ft_calc

# own data exploration functions
import lfpecog_features.tapping_feat_boxplots as fts_boxplot

# own analysing functions

os.chdir(projectpath)
# Out:
# sub functions imported

# %% [markdown]
# ## 1. Varvara's ACC Data - Minute-runs containing multiple 10 second-blocks

# %%
### Future main.py-file

# input from json -> location of data (potential subs to exclude)
# tap_import.create_sub_side_lists() -> available patients + files
# pt-files -> tap_import.accData (class) per sub-side-state
# accClasses -> tapping_run.run_updrs_tapping(already_preprocd)

# %% [markdown]
# ### 1a. Data Import, Extracting and Checking active Tapping-Blocks

# %%
importlib.reload(tap_import)
importlib.reload(find_blocks)

# define folder-directory of tap-data
tap_dir = ('/Users/jeroenhabets/Research/'
            'CHARITE/projects/tapping')
taptask = 'taps_rampStim_3x10s'
verbose=False
toPlot=True
subs_excl = []  #['014', '015']

data_dir = os.path.join(tap_dir, 'data', taptask)
fig_dir = os.path.join(tap_dir, 'figures', taptask)

sub_acc = {}
run_IDs, run_ID_files = tap_import.find_run_IDs(data_dir)
if verbose: print(f'Included subjects/sides to import: {run_IDs}')

subscores = tap_import.tap3x10_updrs_scores(
    file_dir=os.path.join(data_dir, 'updrs_scores'),
    file_name='3x10s_updrs_subscores_all.csv',
    incl_stimRange=True,
)
# Manual correction of error in CSV
del(subscores['007_R_Off']['25mA'])

sub_acc, block_acc, block_ind = {}, {}, {}
for runID in run_IDs:
        
        key = runID[3:]
        if verbose: print('\nSTART', key)
        if key[:3] in subs_excl:
                if verbose: print(f'Skip sub {key}')
                continue

        sub_acc[key] = tap_import.accData(
                OnFile=run_ID_files[runID]['on'],
                OffFile=run_ID_files[runID]['off'],
                orig_fs=250, wanted_fs=250,
                to_resample=False,
                to_check_polarity=True,
                to_check_magnOrder=True,
                verbose=False
        )

        if verbose: print('Acc imported and preprocessed')

        for med in ['Off', 'On']:

                temp_acc, temp_ind = find_blocks.find_active_blocks(
                        acc_arr=getattr(sub_acc[key], med),
                        fs=250, verbose=False, to_plot=False,
                        figsave_dir=fig_dir,
                        figsave_name=f'{key}_{med}_blocks_detected'
                )

                block_acc[f'{key}_{med}'] = temp_acc
                block_ind[f'{key}_{med}'] = temp_ind
                
                if verbose: print(
                        f'\tFor {key}, Med-{med} '
                        f'block-arrays extracted'
                )
# Out:
# 014
# 015
# 007
# 013
# Sub-scores for full stim-Ampltiude range extracted

# %% [markdown]
# #### Manual block-index controle - 3 x 10 sec (only StimOff - stimOn)
#
# Compare the detected blocks in the created figure [SUB_SIDE_MED_blocks_detected] with the blocks which should be rated and included. Adjust the block-number selection if necessary, resulting in corresponding selected block-numbers and block_scores

# %%
### Standard tap-block selection
sel_blocks = {}
for key in block_acc:
    sel_blocks[key] = {'stimOff': [0, 1, 2], 'stimOn': [-9, -8, -7]}
    
### Manual adjustment of tap-block selection based on VISUALISATIONS
sel_blocks['007_L_Off']['stimOff'] = [1, 2, 3]
sel_blocks['007_L_Off']['stimOn'] = [-10, -9, -8]
sel_blocks['013_L_On']['stimOn'] = [-10, -9, -8]
sel_blocks['014_L_Off']['stimOn'] = [-10, -9, -8]

# %%
f = os.path.join(data_dir, 'prep_jsons', 'manual_block_selection_stimOffOnOnly.json')

with open (f, 'w') as jsonfile:

    json.dump(sel_blocks, jsonfile, indent=4)

    jsonfile.close()

# %% [markdown]
# #### Manual block-index controle - 3 x 10 sec (full stim-Amplitude range)

# %%
### Standard tap-block selection

std_indx = {
    '0mA': [0, 1, 2],
    '05mA': [3, 4, 5],
    '1mA': [6, 7, 8],
    '15mA': [9, 10, 11],
    '2mA': [12, 13, 14],
    '25mA': [15, 16, 17],
    '3mA': [18, 19, 20],
}

sel_blocks_amps = {}

for key in subscores:

    sel_blocks_amps[key] = {}

    for amp in subscores[key].keys():

        sel_blocks_amps[key][amp] = std_indx[amp]
    
### Manual adjustment of tap-block selection based on VISUALISATIONS
sel_blocks_amps['007_L_Off'] = {
    '0mA': [1, 2, 3],
    '05mA': [4, 5, 6],
    '1mA': [7, 8, 9],
    '15mA': [11, 12, 13],
    '2mA': [14, 15, 16],
    '25mA': [18, 19, 20],
}

sel_blocks_amps['013_L_Off'] = {
    '0mA': [0, 1, 2],
    '05mA': [3, 4, 5],
    '1mA': [7, 8, 9],
    '15mA': [10, 11, 12],
    '2mA': [13, 14, 15],
    '25mA': [16, 17, 18],
}

sel_blocks_amps['013_L_On'] = {
    '0mA': [0, 1, 2],
    '05mA': [3, 4, 5],
    '1mA': [6, 7, 8],
    '15mA': [9, 10, 11],
    '2mA': [12, 13, 14],
    '25mA': [16, 17, 18],
}

sel_blocks_amps['014_L_Off'] = {
    '0mA': [0, 1, 2],
    '05mA': [6, 7, 8],
    '1mA': [9, 10, 11],
    '15mA': [12, 13, 14],
    '2mA': [15, 16, 17],
    '25mA': [18, 19, 20],
    '3mA': [21, 22, 23]
}

# del(sel_blocks_amps['007_R_Off']['25mA'])

# %%
f = os.path.join(data_dir, 'prep_jsons', 'manual_block_selection_stimAmpRange.json')

with open (f, 'w') as jsonfile:

    json.dump(sel_blocks_amps, jsonfile, indent=4)

    jsonfile.close()

# %% [markdown]
# ### 1b. Feature Extraction per 10-sec block

# %% [markdown]
# #### VISUALISE FEATURES FOR DEVELOPMENT

# %%
fig, axes = plt.subplots(3, 1, figsize=(24, 16))

for i, sub in enumerate([
    '013_L_Off',
    '013_R_Off',
    '007_L_Off'
]):

    print(sub)

    tempacc = block_acc[sub][-8]
    temptap, _, _ = tap_run.run_updrs_tapping(
        acc_arr=tempacc, fs=250, already_preprocd=True,
    )

    axes[i].plot(tempacc.T)
    axes[i].scatter(
        [t[0] for t in temptap],
        [1] * len(temptap),
        color='r',
    )
    axes[i].scatter(
        [t[-1] for t in temptap],
        [1] * len(temptap),
        color='k',
    )
    axes[i].set_xlim(500, 2000)

    slopeChanges = smallSlopeChanges(tempacc)
    tempscore = getattr(FEATS[f'{sub}_S1_b2'], 'updrsSubScore')
    axes[i].set_title(
        f'{sub} UPDRS sub {tempscore}',
        fontsize=18,
    )
    
    print(f'Small slope changes {sub}: {slopeChanges}\n'
            f'\t slopeChanges * nTaps = {slopeChanges * len(temptap)}')

plt.show()
# Out:
# 013_L_Off
# Small slope changes 013_L_Off: 2468
# 	 slopeChanges * nTaps = 29616
# 013_R_Off
# Small slope changes 013_R_Off: 2844
# 	 slopeChanges * nTaps = 93852
# 007_L_Off
# Small slope changes 007_L_Off: 2347
# 	 slopeChanges * nTaps = 35205

# %%
plt.plot(tempacc[1])
plt.xlim(500, 1000)
# Out:
# (500.0, 1000.0)

# %% [markdown]
# #### EXTRACT FEATURES

# %%
importlib.reload(tap_ft_extr)
importlib.reload(tap_fts_set)

block_indx_json = os.path.join(
    data_dir,
    'prep_jsons',
    'manual_block_selection_stimAmpRange.json'
)
 
with open(block_indx_json) as f:
    block_indx = json.load(f, )


FEATS = {}
fs=250
for run in block_acc.keys():
    print(f'start {run}')

    for S, stim in enumerate(subscores[run].keys()):

        for b, block in enumerate([1, 2, 3]):

            tapscore = subscores[run][stim][b]
            block_n = block_indx[run][stim][b]
            tap_acc = block_acc[run][block_n]

            tap_i, imp_i, acc_temp = tap_run.run_updrs_tapping(
                acc_arr=tap_acc, fs=fs, already_preprocd=True,
            )
            
            if len(tap_i) < 1:
                # print(f'No taps detected for {run}_Stim{S}_block {block}')  # for OnOff
                print(f'No taps detected for {run} {stim}_block {block}')  # for Range
                continue

            FEATS[f'{run}_{stim}_b{block}'] = tap_ft_extr.tapFeatures(
                triax_arr=acc_temp,
                fs=fs,
                impacts=imp_i,
                tapDict=tap_i,  # result of continTap
                updrsSubScore=tapscore,
            )
# Out:
# start 007_L_Off
# No taps detected for 007_L_Off 2mA_block 1
# start 007_L_On
# start 007_R_Off
# No taps detected for 007_R_Off 05mA_block 1
# No taps detected for 007_R_Off 05mA_block 3
# No taps detected for 007_R_Off 1mA_block 1
# No taps detected for 007_R_Off 1mA_block 2
# No taps detected for 007_R_Off 1mA_block 3
# No taps detected for 007_R_Off 15mA_block 1
# No taps detected for 007_R_Off 15mA_block 3
# No taps detected for 007_R_Off 2mA_block 1
# No taps detected for 007_R_Off 2mA_block 2
# No taps detected for 007_R_Off 2mA_block 3
# start 007_R_On
# start 014_L_Off
# start 014_L_On
# start 014_R_Off
# start 014_R_On
# start 015_L_Off
# start 015_L_On
# start 015_R_Off
# start 015_R_On
# start 013_L_Off
# start 013_L_On
# start 013_R_Off
# start 013_R_On

# %% [markdown]
# ### 1c. Visualise Features

# %%
importlib.reload(fts_boxplot)
importlib.reload(ft_calc)


ftAx = 'ax'
fts_include = [
    'freq',
    'nTaps',
    'dirChange_run',
    'dirChange_taps',
    f'runRMS_{ftAx}',
    f'tapRMS_{ftAx}',
    f'impactRMS_{ftAx}',
    f'upVelo_{ftAx}',
]
merge_meth = 'median'
# for merge_meth in ['mean', 'sum', 'stddev', 'trend_slope']:
tempScoreDict = fts_boxplot.combineFeatsPerScore(
    ftDict=FEATS, fts_include=fts_include,
    merge_method=merge_meth,
)
fts_boxplot.plot_boxplot_feats_per_subscore(
    fts_include=fts_include,
    featDict=tempScoreDict,
    merge_method=merge_meth,
    plot_title='Stim-Ramp 3x10sec Tapping',
    figsave_name=f'stimRamp_3x10_4pts_{ftAx}Fts_{merge_meth}',
    figsave_dir=os.path.join(fig_dir, 'results_fullRange'),
    show=False,
)

# %% [markdown]
# ## 2. Johannes ACC Data - Individual 30 second-runs, only tapping

# %% [markdown]
# #### 2a. Feature Extraction and Visualisation of sub with UPDRS-subscores

# %%
importlib.reload(tap_run)
importlib.reload(tap_times)
importlib.reload(tap_ft_extr)
importlib.reload(tap_fts_set)
importlib.reload(tap_import)
importlib.reload(tap_impact)
importlib.reload(tap_preproc)

# define directory and filename
jb_dir = '/Users/jeroenhabets/Research/CHARITE/projects/tapping/data/JB_30s'
jb_fig_dir = '/Users/jeroenhabets/Research/CHARITE/projects/tapping/figures/JB_30s'

mat_dat_f = 'tapsMat.mat'
mat_ax_ids_f = 'channels.mat'
mat_run_ids_f = 'subSession.mat'

# Import acc-traces
mat = tap_import.matlab_import(os.path.join(
    jb_dir, mat_dat_f))
fname = mat.filename.split(sep='/')[-1]
mat = mat[fname[:-4]]

# Import subscores
scores218 = np.genfromtxt(
    os.path.join(jb_dir, 'updrs_218.txt'),
    delimiter=',', dtype=str,
)
df_scores218 = pd.DataFrame(data=scores218[1:, :], columns=scores218[0, :])
arr_scores218 = scores218[1:, 2:]
scores545 = arr_scores218[-28:,:]

fs=250

acc545 = mat[:, :, -28:]
fts545 = {}

# ### check tap detection
tap545 = {}
imp545 = {}
accproc545 = {}

updrs_times = {'t1': (2 * fs, 12 * fs), 't2': (20 * fs, 30 * fs)}

accDat = acc545

for run_id in np.arange(acc545.shape[2]):
    
    raw_triax = acc545[:, :, run_id].T

    for t_i, t in enumerate(updrs_times.keys()):

        # print(f'\nStart run_id {run_id}, timepoint {t_i}')

        sig = raw_triax[
            :, updrs_times[t][0]:updrs_times[t][1]
        ]
        subscore = scores545[run_id, t_i]

        tap_inds, imp_inds, proc_triax = tap_run.run_updrs_tapping(
            acc_arr=sig, fs=fs, already_preprocd=False, #orig_fs=4000,
        )
        # ## check tap detect
        tap545[f'run{run_id}_t{t_i}'] = tap_inds
        imp545[f'run{run_id}_t{t_i}'] = imp_inds
        accproc545[f'run{run_id}_t{t_i}'] = proc_triax

        fts545[f'run{run_id}_t{t_i}'] = tap_ft_extr.tapFeatures(
            triax_arr=proc_triax,
            fs=fs,
            impacts=imp_inds,
            tapDict=tap_inds,  # result of continTap
            updrsSubScore=subscore,
        )
# Out:
# Start run_id 0, timepoint 0
#
# Start run_id 0, timepoint 1
#
# Start run_id 1, timepoint 0
#
# Start run_id 1, timepoint 1
#
# Start run_id 2, timepoint 0
#
# Start run_id 2, timepoint 1
#
# Start run_id 3, timepoint 0
#
# Start run_id 3, timepoint 1
#
# Start run_id 4, timepoint 0
#
# Start run_id 4, timepoint 1
#
# Start run_id 5, timepoint 0
#
# Start run_id 5, timepoint 1
#
# Start run_id 6, timepoint 0
#
# Start run_id 6, timepoint 1
#
# Start run_id 7, timepoint 0
#
# Start run_id 7, timepoint 1
#
# Start run_id 8, timepoint 0
#
# Start run_id 8, timepoint 1
#
# Start run_id 9, timepoint 0
#
# Start run_id 9, timepoint 1
#
# Start run_id 10, timepoint 0
#
# Start run_id 10, timepoint 1
#
# Start run_id 11, timepoint 0
#
# Start run_id 11, timepoint 1
#
# Start run_id 12, timepoint 0
#
# Start run_id 12, timepoint 1
#
# Start run_id 13, timepoint 0
#
# Start run_id 13, timepoint 1
#
# Start run_id 14, timepoint 0
#
# Start run_id 14, timepoint 1
#
# Start run_id 15, timepoint 0
#
# Start run_id 15, timepoint 1
# Pos/Neg switched
#
# Start run_id 16, timepoint 0
#
# Start run_id 16, timepoint 1
#
# Start run_id 17, timepoint 0
#
# Start run_id 17, timepoint 1
#
# Start run_id 18, timepoint 0
#
# Start run_id 18, timepoint 1
#
# Start run_id 19, timepoint 0
#
# Start run_id 19, timepoint 1
#
# Start run_id 20, timepoint 0
#
# Start run_id 20, timepoint 1
#
# Start run_id 21, timepoint 0
#
# Start run_id 21, timepoint 1
#
# Start run_id 22, timepoint 0
#
# Start run_id 22, timepoint 1
#
# Start run_id 23, timepoint 0
#
# Start run_id 23, timepoint 1
#
# Start run_id 24, timepoint 0
#
# Start run_id 24, timepoint 1
#
# Start run_id 25, timepoint 0
#
# Start run_id 25, timepoint 1
#
# Start run_id 26, timepoint 0
#
# Start run_id 26, timepoint 1
#
# Start run_id 27, timepoint 0
#
# Start run_id 27, timepoint 1

# %% [markdown]
# For Johannes -> EXTRACT FROM ALL TRACES AND SAVE; INCL dirChanges as CoefOfVar!!

# %%
fts_include = [
    'freq',
    'nTaps',
    'tapRMS_ax',
    'impactRMS_ax',
    'dirChange_taps',
    'upVelo_ax'
]
merge_meth = 'mean'

tempScoreDict = fts_boxplot.combineFeatsPerScore(
    ftDict=fts545, fts_include=fts_include,
    merge_method=merge_meth,
)
fts_boxplot.plot_boxplot_feats_per_subscore(
    fts_include=fts_include,
    featDict=tempScoreDict,
    merge_method=merge_meth,
    plot_title='545 28 aDBS traces',
    figsave_name='',  # f'sub545_aDBS_box5fts_{merge_meth}',
    figsave_dir=jb_fig_dir,
    show=False,
)

# %% [markdown]
# #### 2b. Extract Features and Store them for Subs without UPDRS-subscores

# %%
mat.shape
# Out:
# (8001, 3, 218)

# %%
importlib.reload(tap_run)
importlib.reload(tap_times)
importlib.reload(tap_ft_extr)
importlib.reload(tap_fts_set)
importlib.reload(tap_import)
importlib.reload(tap_impact)
importlib.reload(tap_preproc)

# define directory and filename
jb_dir = '/Users/jeroenhabets/Research/CHARITE/projects/tapping/data/JB_30s'
jb_fig_dir = '/Users/jeroenhabets/Research/CHARITE/projects/tapping/figures/JB_30s'

mat_dat_f = 'tapsMat.mat'
mat_ax_ids_f = 'channels.mat'
mat_run_ids_f = 'subSession.mat'

# Import acc-traces
mat = tap_import.matlab_import(os.path.join(
    jb_dir, mat_dat_f))
fname = mat.filename.split(sep='/')[-1]
mat = mat[fname[:-4]]

fs=250

accAll = mat[:, :, :]
ftsAll = {}

updrs_times = {'t1': (2 * fs, 12 * fs), 't2': (20 * fs, 30 * fs)}

for run_id in np.arange(accAll.shape[2]):
    
    raw_triax = accAll[:, :, run_id].T

    for t_i, t in enumerate(updrs_times.keys()):

        # print(f'\nStart run_id {run_id}, timepoint {t_i}')

        sig = raw_triax[
            :, updrs_times[t][0]:updrs_times[t][1]
        ]

        tap_inds, imp_inds, proc_triax = tap_run.run_updrs_tapping(
            acc_arr=sig, fs=fs, already_preprocd=False,
        )

        ftsAll[f'run{run_id}_t{t_i}'] = tap_ft_extr.tapFeatures(
            triax_arr=proc_triax,
            fs=fs,
            impacts=imp_inds,
            tapDict=tap_inds,  # result of continTap
            updrsSubScore=subscore,
        )
# Out:
# Start run_id 0, timepoint 0
# Pos/Neg switched
#
# Start run_id 0, timepoint 1
#
# Start run_id 1, timepoint 0
# Pos/Neg switched
#
# Start run_id 1, timepoint 1
#
# Start run_id 2, timepoint 0
# Pos/Neg switched
#
# Start run_id 2, timepoint 1
#
# Start run_id 3, timepoint 0
# Pos/Neg switched
#
# Start run_id 3, timepoint 1
#
# Start run_id 4, timepoint 0
# Pos/Neg switched
#
# Start run_id 4, timepoint 1
#
# Start run_id 5, timepoint 0
#
# Start run_id 5, timepoint 1
#
# Start run_id 6, timepoint 0
#
# Start run_id 6, timepoint 1
#
# Start run_id 7, timepoint 0
#
# Start run_id 7, timepoint 1
#
# Start run_id 8, timepoint 0
#
# Start run_id 8, timepoint 1
#
# Start run_id 9, timepoint 0
#
# Start run_id 9, timepoint 1
#
# Start run_id 10, timepoint 0
# Pos/Neg switched
#
# Start run_id 10, timepoint 1
#
# Start run_id 11, timepoint 0
# Pos/Neg switched
#
# Start run_id 11, timepoint 1
# Pos/Neg switched
#
# Start run_id 12, timepoint 0
# Pos/Neg switched
#
# Start run_id 12, timepoint 1
# Pos/Neg switched
#
# Start run_id 13, timepoint 0
# Pos/Neg switched
#
# Start run_id 13, timepoint 1
# Pos/Neg switched
#
# Start run_id 14, timepoint 0
# Pos/Neg switched
#
# Start run_id 14, timepoint 1
# Pos/Neg switched
#
# Start run_id 15, timepoint 0
# Pos/Neg switched
#
# Start run_id 15, timepoint 1
# Pos/Neg switched
#
# Start run_id 16, timepoint 0
# Pos/Neg switched
#
# Start run_id 16, timepoint 1
# Pos/Neg switched
#
# Start run_id 17, timepoint 0
# Pos/Neg switched
#
# Start run_id 17, timepoint 1
# Pos/Neg switched
#
# Start run_id 18, timepoint 0
# Pos/Neg switched
#
# Start run_id 18, timepoint 1
# Pos/Neg switched
#
# Start run_id 19, timepoint 0
# Pos/Neg switched
#
# Start run_id 19, timepoint 1
# Pos/Neg switched
#
# Start run_id 20, timepoint 0
# Pos/Neg switched
#
# Start run_id 20, timepoint 1
# Pos/Neg switched
#
# Start run_id 21, timepoint 0
#
# Start run_id 21, timepoint 1
# Pos/Neg switched
#
# Start run_id 22, timepoint 0
# Pos/Neg switched
#
# Start run_id 22, timepoint 1
# Pos/Neg switched
#
# Start run_id 23, timepoint 0
#
# Start run_id 23, timepoint 1
# Pos/Neg switched
#
# Start run_id 24, timepoint 0
#
# Start run_id 24, timepoint 1
# Pos/Neg switched
#
# Start run_id 25, timepoint 0
#
# Start run_id 25, timepoint 1
#
# Start run_id 26, timepoint 0
#
# Start run_id 26, timepoint 1
#
# Start run_id 27, timepoint 0
# Pos/Neg switched
#
# Start run_id 27, timepoint 1
#
# Start run_id 28, timepoint 0
# Pos/Neg switched
#
# Start run_id 28, timepoint 1
# Pos/Neg switched
#
# Start run_id 29, timepoint 0
# Pos/Neg switched
#
# Start run_id 29, timepoint 1
# Pos/Neg switched
#
# Start run_id 30, timepoint 0
#
# Start run_id 30, timepoint 1
#
# Start run_id 31, timepoint 0
# Pos/Neg switched
#
# Start run_id 31, timepoint 1
#
# Start run_id 32, timepoint 0
# Pos/Neg switched
#
# Start run_id 32, timepoint 1
#
# Start run_id 33, timepoint 0
#
# Start run_id 33, timepoint 1
#
# Start run_id 34, timepoint 0
#
# Start run_id 34, timepoint 1
#
# Start run_id 35, timepoint 0
#
# Start run_id 35, timepoint 1
#
# Start run_id 36, timepoint 0
#
# Start run_id 36, timepoint 1
#
# Start run_id 37, timepoint 0
#
# Start run_id 37, timepoint 1
#
# Start run_id 38, timepoint 0
#
# Start run_id 38, timepoint 1
#
# Start run_id 39, timepoint 0
#
# Start run_id 39, timepoint 1
#
# Start run_id 40, timepoint 0
#
# Start run_id 40, timepoint 1
#
# Start run_id 41, timepoint 0
#
# Start run_id 41, timepoint 1
#
# Start run_id 42, timepoint 0
#
# Start run_id 42, timepoint 1
#
# Start run_id 43, timepoint 0
#
# Start run_id 43, timepoint 1
#
# Start run_id 44, timepoint 0
# Pos/Neg switched
#
# Start run_id 44, timepoint 1
# Pos/Neg switched
#
# Start run_id 45, timepoint 0
# Pos/Neg switched
#
# Start run_id 45, timepoint 1
# Pos/Neg switched
#
# Start run_id 46, timepoint 0
# Pos/Neg switched
#
# Start run_id 46, timepoint 1
# Pos/Neg switched
#
# Start run_id 47, timepoint 0
# Pos/Neg switched
#
# Start run_id 47, timepoint 1
# Pos/Neg switched
#
# Start run_id 48, timepoint 0
# Pos/Neg switched
#
# Start run_id 48, timepoint 1
# Pos/Neg switched
#
# Start run_id 49, timepoint 0
# Pos/Neg switched
#
# Start run_id 49, timepoint 1
# Pos/Neg switched
#
# Start run_id 50, timepoint 0
# Pos/Neg switched
#
# Start run_id 50, timepoint 1
# Pos/Neg switched
#
# Start run_id 51, timepoint 0
# Pos/Neg switched
#
# Start run_id 51, timepoint 1
# Pos/Neg switched
#
# Start run_id 52, timepoint 0
# Pos/Neg switched
#
# Start run_id 52, timepoint 1
# Pos/Neg switched
#
# Start run_id 53, timepoint 0
# Pos/Neg switched
#
# Start run_id 53, timepoint 1
# Pos/Neg switched
#
# Start run_id 54, timepoint 0
# Pos/Neg switched
#
# Start run_id 54, timepoint 1
# Pos/Neg switched
#
# Start run_id 55, timepoint 0
# Pos/Neg switched
#
# Start run_id 55, timepoint 1
# Pos/Neg switched
#
# Start run_id 56, timepoint 0
# Pos/Neg switched
#
# Start run_id 56, timepoint 1
# Pos/Neg switched
#
# Start run_id 57, timepoint 0
# Pos/Neg switched
#
# Start run_id 57, timepoint 1
# Pos/Neg switched
#
# Start run_id 58, timepoint 0
# Pos/Neg switched
#
# Start run_id 58, timepoint 1
# Pos/Neg switched
#
# Start run_id 59, timepoint 0
# Pos/Neg switched
#
# Start run_id 59, timepoint 1
# Pos/Neg switched
#
# Start run_id 60, timepoint 0
# Pos/Neg switched
#
# Start run_id 60, timepoint 1
# Pos/Neg switched
#
# Start run_id 61, timepoint 0
# Pos/Neg switched
#
# Start run_id 61, timepoint 1
# Pos/Neg switched
#
# Start run_id 62, timepoint 0
# Pos/Neg switched
#
# Start run_id 62, timepoint 1
# Pos/Neg switched
#
# Start run_id 63, timepoint 0
# Pos/Neg switched
#
# Start run_id 63, timepoint 1
#
# Start run_id 64, timepoint 0
# Pos/Neg switched
#
# Start run_id 64, timepoint 1
# Pos/Neg switched
#
# Start run_id 65, timepoint 0
# Pos/Neg switched
#
# Start run_id 65, timepoint 1
# Pos/Neg switched
#
# Start run_id 66, timepoint 0
#
# Start run_id 66, timepoint 1
# Pos/Neg switched
#
# Start run_id 67, timepoint 0
#
# Start run_id 67, timepoint 1
#
# Start run_id 68, timepoint 0
#
# Start run_id 68, timepoint 1
#
# Start run_id 69, timepoint 0
#
# Start run_id 69, timepoint 1
#
# Start run_id 70, timepoint 0
#
# Start run_id 70, timepoint 1
#
# Start run_id 71, timepoint 0
#
# Start run_id 71, timepoint 1
#
# Start run_id 72, timepoint 0
#
# Start run_id 72, timepoint 1
#
# Start run_id 73, timepoint 0
#
# Start run_id 73, timepoint 1
#
# Start run_id 74, timepoint 0
# Pos/Neg switched
#
# Start run_id 74, timepoint 1
#
# Start run_id 75, timepoint 0
#
# Start run_id 75, timepoint 1
#
# Start run_id 76, timepoint 0
#
# Start run_id 76, timepoint 1
# Pos/Neg switched
#
# Start run_id 77, timepoint 0
# Pos/Neg switched
# /Users/jeroenhabets/Research/CHARITE/projects/dyskinesia_neurophys/code/lfpecog_features/tapping_extract_features.py:49: RuntimeWarning: Mean of empty slice.
#   self.freq2 = round(1 / self.tap_durations.mean(), 1)
# /Users/jeroenhabets/anaconda3/envs/ecog_dysk/lib/python3.9/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Start run_id 77, timepoint 1
# Pos/Neg switched
#
# Start run_id 78, timepoint 0
# Pos/Neg switched
#
# Start run_id 78, timepoint 1
# Pos/Neg switched
#
# Start run_id 79, timepoint 0
# Pos/Neg switched
#
# Start run_id 79, timepoint 1
# Pos/Neg switched
#
# Start run_id 80, timepoint 0
# Pos/Neg switched
#
# Start run_id 80, timepoint 1
# Pos/Neg switched
#
# Start run_id 81, timepoint 0
# Pos/Neg switched
#
# Start run_id 81, timepoint 1
# Pos/Neg switched
#
# Start run_id 82, timepoint 0
# Pos/Neg switched
#
# Start run_id 82, timepoint 1
# Pos/Neg switched
#
# Start run_id 83, timepoint 0
# Pos/Neg switched
#
# Start run_id 83, timepoint 1
# Pos/Neg switched
#
# Start run_id 84, timepoint 0
# Pos/Neg switched
#
# Start run_id 84, timepoint 1
# Pos/Neg switched
#
# Start run_id 85, timepoint 0
# Pos/Neg switched
#
# Start run_id 85, timepoint 1
# Pos/Neg switched
#
# Start run_id 86, timepoint 0
# Pos/Neg switched
#
# Start run_id 86, timepoint 1
# Pos/Neg switched
#
# Start run_id 87, timepoint 0
# Pos/Neg switched
#
# Start run_id 87, timepoint 1
# Pos/Neg switched
#
# Start run_id 88, timepoint 0
#
# Start run_id 88, timepoint 1
#
# Start run_id 89, timepoint 0
#
# Start run_id 89, timepoint 1
#
# Start run_id 90, timepoint 0
#
# Start run_id 90, timepoint 1
#
# Start run_id 91, timepoint 0
#
# Start run_id 91, timepoint 1
#
# Start run_id 92, timepoint 0
#
# Start run_id 92, timepoint 1
#
# Start run_id 93, timepoint 0
#
# Start run_id 93, timepoint 1
#
# Start run_id 94, timepoint 0
#
# Start run_id 94, timepoint 1
#
# Start run_id 95, timepoint 0
#
# Start run_id 95, timepoint 1
#
# Start run_id 96, timepoint 0
#
# Start run_id 96, timepoint 1
#
# Start run_id 97, timepoint 0
#
# Start run_id 97, timepoint 1
#
# Start run_id 98, timepoint 0
#
# Start run_id 98, timepoint 1
#
# Start run_id 99, timepoint 0
# Pos/Neg switched
#
# Start run_id 99, timepoint 1
#
# Start run_id 100, timepoint 0
# Pos/Neg switched
#
# Start run_id 100, timepoint 1
# Pos/Neg switched
#
# Start run_id 101, timepoint 0
# Pos/Neg switched
#
# Start run_id 101, timepoint 1
# Pos/Neg switched
#
# Start run_id 102, timepoint 0
# Pos/Neg switched
#
# Start run_id 102, timepoint 1
# Pos/Neg switched
#
# Start run_id 103, timepoint 0
# Pos/Neg switched
#
# Start run_id 103, timepoint 1
#
# Start run_id 104, timepoint 0
# Pos/Neg switched
#
# Start run_id 104, timepoint 1
# Pos/Neg switched
#
# Start run_id 105, timepoint 0
# Pos/Neg switched
#
# Start run_id 105, timepoint 1
# Pos/Neg switched
#
# Start run_id 106, timepoint 0
# Pos/Neg switched
#
# Start run_id 106, timepoint 1
#
# Start run_id 107, timepoint 0
# Pos/Neg switched
#
# Start run_id 107, timepoint 1
#
# Start run_id 108, timepoint 0
# Pos/Neg switched
#
# Start run_id 108, timepoint 1
# Pos/Neg switched
#
# Start run_id 109, timepoint 0
# Pos/Neg switched
#
# Start run_id 109, timepoint 1
# Pos/Neg switched
#
# Start run_id 110, timepoint 0
#
# Start run_id 110, timepoint 1
#
# Start run_id 111, timepoint 0
#
# Start run_id 111, timepoint 1
#
# Start run_id 112, timepoint 0
#
# Start run_id 112, timepoint 1
#
# Start run_id 113, timepoint 0
#
# Start run_id 113, timepoint 1
#
# Start run_id 114, timepoint 0
#
# Start run_id 114, timepoint 1
#
# Start run_id 115, timepoint 0
#
# Start run_id 115, timepoint 1
#
# Start run_id 116, timepoint 0
#
# Start run_id 116, timepoint 1
#
# Start run_id 117, timepoint 0
#
# Start run_id 117, timepoint 1
#
# Start run_id 118, timepoint 0
#
# Start run_id 118, timepoint 1
#
# Start run_id 119, timepoint 0
#
# Start run_id 119, timepoint 1
#
# Start run_id 120, timepoint 0
#
# Start run_id 120, timepoint 1
#
# Start run_id 121, timepoint 0
#
# Start run_id 121, timepoint 1
#
# Start run_id 122, timepoint 0
#
# Start run_id 122, timepoint 1
#
# Start run_id 123, timepoint 0
#
# Start run_id 123, timepoint 1
#
# Start run_id 124, timepoint 0
#
# Start run_id 124, timepoint 1
#
# Start run_id 125, timepoint 0
#
# Start run_id 125, timepoint 1
#
# Start run_id 126, timepoint 0
#
# Start run_id 126, timepoint 1
#
# Start run_id 127, timepoint 0
#
# Start run_id 127, timepoint 1
#
# Start run_id 128, timepoint 0
#
# Start run_id 128, timepoint 1
#
# Start run_id 129, timepoint 0
#
# Start run_id 129, timepoint 1
#
# Start run_id 130, timepoint 0
#
# Start run_id 130, timepoint 1
#
# Start run_id 131, timepoint 0
#
# Start run_id 131, timepoint 1
#
# Start run_id 132, timepoint 0
#
# Start run_id 132, timepoint 1
#
# Start run_id 133, timepoint 0
#
# Start run_id 133, timepoint 1
#
# Start run_id 134, timepoint 0
#
# Start run_id 134, timepoint 1
#
# Start run_id 135, timepoint 0
#
# Start run_id 135, timepoint 1
#
# Start run_id 136, timepoint 0
#
# Start run_id 136, timepoint 1
#
# Start run_id 137, timepoint 0
#
# Start run_id 137, timepoint 1
#
# Start run_id 138, timepoint 0
# Pos/Neg switched
#
# Start run_id 138, timepoint 1
#
# Start run_id 139, timepoint 0
# Pos/Neg switched
#
# Start run_id 139, timepoint 1
#
# Start run_id 140, timepoint 0
#
# Start run_id 140, timepoint 1
#
# Start run_id 141, timepoint 0
#
# Start run_id 141, timepoint 1
#
# Start run_id 142, timepoint 0
#
# Start run_id 142, timepoint 1
#
# Start run_id 143, timepoint 0
#
# Start run_id 143, timepoint 1
#
# Start run_id 144, timepoint 0
#
# Start run_id 144, timepoint 1
#
# Start run_id 145, timepoint 0
#
# Start run_id 145, timepoint 1
#
# Start run_id 146, timepoint 0
#
# Start run_id 146, timepoint 1
#
# Start run_id 147, timepoint 0
#
# Start run_id 147, timepoint 1
#
# Start run_id 148, timepoint 0
#
# Start run_id 148, timepoint 1
#
# Start run_id 149, timepoint 0
#
# Start run_id 149, timepoint 1
#
# Start run_id 150, timepoint 0
#
# Start run_id 150, timepoint 1
#
# Start run_id 151, timepoint 0
#
# Start run_id 151, timepoint 1
#
# Start run_id 152, timepoint 0
#
# Start run_id 152, timepoint 1
#
# Start run_id 153, timepoint 0
#
# Start run_id 153, timepoint 1
#
# Start run_id 154, timepoint 0
#
# Start run_id 154, timepoint 1
#
# Start run_id 155, timepoint 0
#
# Start run_id 155, timepoint 1
#
# Start run_id 156, timepoint 0
#
# Start run_id 156, timepoint 1
#
# Start run_id 157, timepoint 0
#
# Start run_id 157, timepoint 1
#
# Start run_id 158, timepoint 0
#
# Start run_id 158, timepoint 1
#
# Start run_id 159, timepoint 0
#
# Start run_id 159, timepoint 1
#
# Start run_id 160, timepoint 0
#
# Start run_id 160, timepoint 1
#
# Start run_id 161, timepoint 0
#
# Start run_id 161, timepoint 1
#
# Start run_id 162, timepoint 0
#
# Start run_id 162, timepoint 1
#
# Start run_id 163, timepoint 0
#
# Start run_id 163, timepoint 1
#
# Start run_id 164, timepoint 0
#
# Start run_id 164, timepoint 1
#
# Start run_id 165, timepoint 0
#
# Start run_id 165, timepoint 1
#
# Start run_id 166, timepoint 0
#
# Start run_id 166, timepoint 1
#
# Start run_id 167, timepoint 0
#
# Start run_id 167, timepoint 1
#
# Start run_id 168, timepoint 0
#
# Start run_id 168, timepoint 1
#
# Start run_id 169, timepoint 0
#
# Start run_id 169, timepoint 1
#
# Start run_id 170, timepoint 0
#
# Start run_id 170, timepoint 1
#
# Start run_id 171, timepoint 0
#
# Start run_id 171, timepoint 1
#
# Start run_id 172, timepoint 0
#
# Start run_id 172, timepoint 1
#
# Start run_id 173, timepoint 0
#
# Start run_id 173, timepoint 1
#
# Start run_id 174, timepoint 0
#
# Start run_id 174, timepoint 1
#
# Start run_id 175, timepoint 0
#
# Start run_id 175, timepoint 1
#
# Start run_id 176, timepoint 0
#
# Start run_id 176, timepoint 1
#
# Start run_id 177, timepoint 0
#
# Start run_id 177, timepoint 1
#
# Start run_id 178, timepoint 0
#
# Start run_id 178, timepoint 1
#
# Start run_id 179, timepoint 0
#
# Start run_id 179, timepoint 1
#
# Start run_id 180, timepoint 0
#
# Start run_id 180, timepoint 1
#
# Start run_id 181, timepoint 0
#
# Start run_id 181, timepoint 1
#
# Start run_id 182, timepoint 0
#
# Start run_id 182, timepoint 1
#
# Start run_id 183, timepoint 0
#
# Start run_id 183, timepoint 1
#
# Start run_id 184, timepoint 0
#
# Start run_id 184, timepoint 1
#
# Start run_id 185, timepoint 0
#
# Start run_id 185, timepoint 1
#
# Start run_id 186, timepoint 0
#
# Start run_id 186, timepoint 1
#
# Start run_id 187, timepoint 0
#
# Start run_id 187, timepoint 1
#
# Start run_id 188, timepoint 0
#
# Start run_id 188, timepoint 1
#
# Start run_id 189, timepoint 0
#
# Start run_id 189, timepoint 1
#
# Start run_id 190, timepoint 0
#
# Start run_id 190, timepoint 1
#
# Start run_id 191, timepoint 0
#
# Start run_id 191, timepoint 1
#
# Start run_id 192, timepoint 0
#
# Start run_id 192, timepoint 1
#
# Start run_id 193, timepoint 0
#
# Start run_id 193, timepoint 1
#
# Start run_id 194, timepoint 0
#
# Start run_id 194, timepoint 1
#
# Start run_id 195, timepoint 0
#
# Start run_id 195, timepoint 1
#
# Start run_id 196, timepoint 0
#
# Start run_id 196, timepoint 1
#
# Start run_id 197, timepoint 0
#
# Start run_id 197, timepoint 1
#
# Start run_id 198, timepoint 0
#
# Start run_id 198, timepoint 1
#
# Start run_id 199, timepoint 0
#
# Start run_id 199, timepoint 1
#
# Start run_id 200, timepoint 0
#
# Start run_id 200, timepoint 1
#
# Start run_id 201, timepoint 0
#
# Start run_id 201, timepoint 1
#
# Start run_id 202, timepoint 0
#
# Start run_id 202, timepoint 1
#
# Start run_id 203, timepoint 0
#
# Start run_id 203, timepoint 1
#
# Start run_id 204, timepoint 0
#
# Start run_id 204, timepoint 1
#
# Start run_id 205, timepoint 0
#
# Start run_id 205, timepoint 1
# Pos/Neg switched
#
# Start run_id 206, timepoint 0
#
# Start run_id 206, timepoint 1
#
# Start run_id 207, timepoint 0
#
# Start run_id 207, timepoint 1
#
# Start run_id 208, timepoint 0
#
# Start run_id 208, timepoint 1
#
# Start run_id 209, timepoint 0
#
# Start run_id 209, timepoint 1
#
# Start run_id 210, timepoint 0
#
# Start run_id 210, timepoint 1
#
# Start run_id 211, timepoint 0
#
# Start run_id 211, timepoint 1
#
# Start run_id 212, timepoint 0
#
# Start run_id 212, timepoint 1
#
# Start run_id 213, timepoint 0
#
# Start run_id 213, timepoint 1
#
# Start run_id 214, timepoint 0
#
# Start run_id 214, timepoint 1
#
# Start run_id 215, timepoint 0
#
# Start run_id 215, timepoint 1
#
# Start run_id 216, timepoint 0
#
# Start run_id 216, timepoint 1
#
# Start run_id 217, timepoint 0
#
# Start run_id 217, timepoint 1

# %%
vars(ftsAll['run0_t0']).keys()
# Out:
# dict_keys(['triax_arr', 'fs', 'impacts', 'tapDict', 'updrsSubScore', 'nTaps', 'freq', 'tap_durations', 'freq2', 'runRMS_ax', 'runRMS_svm', 'tapRMS_ax', 'tapRMS_svm', 'upVelo_ax', 'upVelo_svm', 'impactRMS_ax', 'impactRMS_svm', 'dirChange_run', 'dirChange_taps'])

# %%
importlib.reload(ft_calc)

ft_sel = [
    'nTaps',
    'freq',
    'tapRMS_ax',
    'impactRMS_ax',
    'upVelo_svm',
    'dirChange_taps',
]

ft_colNames = [
    'nTaps',
    'freq',
    'tapRMS_ax_mean',
    'impactRMS_ax_mean',
    'upVelo_svm_mean',
    'dirChange_taps_coefVar',
]

fts_df = pd.DataFrame(
    data=ft_calc.nan_array([
        len(ftsAll.keys()), len(ft_sel)
    ]),
    columns=ft_sel,
    index=ftsAll.keys(),
)


for run_id in ftsAll.keys():

    for ft in ft_sel:
        
        value = getattr(ftsAll[run_id], ft)

        if ft in ['nTaps', 'freq']:
            value = value
        
        elif ft == 'dirChange_taps':
            value = ft_calc.aggregate_arr_fts(
                'coefVar', value
            )
        
        else:
            value = ft_calc.aggregate_arr_fts(
                'mean', value
            )
        
        fts_df.loc[run_id][ft] = value


fts_df.to_csv(
    os.path.join(
        '/Users/jeroenhabets/Research/CHARITE/projects/tapping/results/JB_30s',
        'table_218subs_6fts.csv'
    ),
    header=True, index=True,
)
# Out:
# /Users/jeroenhabets/Research/CHARITE/projects/dyskinesia_neurophys/code/lfpecog_features/tapping_feat_calc.py:87: RuntimeWarning: invalid value encountered in true_divide
#   print(values)
# artificial 0 added
# artificial 0 added
# artificial 0 added
# artificial 0 added

# %% [markdown]
# # 3. Clustering & Classifying

# %% [markdown]
# - Candidate vetors based on descriptives and concept
#     - nTaps
#     - freq
#     - upVelo sum [std-dev + coefVar]
#     - impact RMS [coefVar + stddev]
#     - tapRMS and impactRMS [sum]
#     -
# - include per run (array tap-features): sum, mean, stddev, trend_slope
#
# - Cluster on UPDRS 4?

# %% [markdown]
# ### 3a. ML-Vector Preparation

# %%
importlib.reload(ft_calc)

ft_axis = 'ax'
single_ft_names = ['nTaps', 'freq',]
arr_ft_names = [
    f'tapRMS_{ft_axis}',
    f'upVelo_{ft_axis}',
    f'impactRMS_{ft_axis}',
    'dirChange_taps',
]
ft_aggr_to_add = [
    'mean', 'stddev', 'sum', 'trend_slope'
]

n_samples = len(FEATS.keys())

Xdf = pd.DataFrame(
    data=np.zeros((
        n_samples,
        len(single_ft_names) + (len(arr_ft_names) * 4)
    )), columns=[single_ft_names + [
        f'{f}_{m}' for f in arr_ft_names for m in ft_aggr_to_add
    ]]
)
y = ft_calc.nan_array([Xdf.shape[0], 1])
for s in range(Xdf.shape[0]):
    y[s] = getattr(
        FEATS[list(FEATS.keys())[s]],
        'updrsSubScore'
    )

for ft in single_ft_names:
    for s, sam in enumerate(FEATS.keys()):
        ft_value = getattr(FEATS[sam], ft)
        Xdf.iloc[s][ft] = ft_value


max_nTaps = np.max([FEATS[k].nTaps for k in FEATS.keys()])

arr_feats = ft_calc.nan_array([
    len(arr_ft_names),
    max_nTaps,
    n_samples
])

for f, ft in enumerate(arr_ft_names):

    for s, sam in enumerate(FEATS.keys()):

        ft_values = getattr(FEATS[sam], ft)
        arr_feats[f, :len(ft_values), s] = ft_values

# Normalise vector per array-feature over all samples
for ft_row in range(len(arr_ft_names)):

    vec_max = np.nanmax(arr_feats[ft_row, :, :])
    arr_feats[ft_row, :, :] = arr_feats[ft_row, :, :] / vec_max

# Normalise single feature over all samples
for ft in single_ft_names:

    fmax = np.max(Xdf[ft])
    Xdf[ft] = Xdf[ft] / fmax

# Aggregate array features
for ft, ft_name in enumerate(arr_ft_names):

    for m in ft_aggr_to_add:

        for s in np.arange(Xdf.shape[0]):
            
            value = ft_calc.aggregate_arr_fts(
                method=m, arr=arr_feats[ft, :, s]
            )
            
            Xdf.iloc[s][f'{ft_name}_{m}'] = value

### assert np.sum(np.isnan(Xdf.values)) == 0
X = Xdf.values
# Out:
# /Users/jeroenhabets/anaconda3/envs/ecog_dysk/lib/python3.9/site-packages/scipy/stats/_stats_mstats_common.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   slope = ssxym / ssxm
# /Users/jeroenhabets/anaconda3/envs/ecog_dysk/lib/python3.9/site-packages/scipy/stats/_stats_mstats_common.py:184: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/jeroenhabets/anaconda3/envs/ecog_dysk/lib/python3.9/site-packages/scipy/stats/_stats_mstats_common.py:187: RuntimeWarning: invalid value encountered in double_scalars
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %% [markdown]
# ### 3b. Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# DBSCAN
# Laio

# %%
### Cluster Settings
## test with full features and PCA1-2;
## test first PCA cluster and full-fts classification within clusters
n_clusters = 4


X = Xdf.values
pca = PCA(2)
# X = pca.fit_transform(X)

kmeans = KMeans(
    n_clusters=n_clusters,
    random_state=27
)
y_clust_labels = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_

y_cluster0 = y[y_clust_labels == 0]
y_cluster1 = y[y_clust_labels == 1]

score_cols = {
    0: 'green',
    1: 'blue',
    2: 'orange',
    3: 'red',
    4: 'purple'
}

clMarkers = ['o', 'x', '*', '+', '^']

fig, ax = plt.subplots(1, 1, figsize=(12, 12))
s = 75
for n, X_pca_row in enumerate(X):

    score = int(y[n])
    col = score_cols[score]

    for clN in range(n_clusters):

        if y_clust_labels[n] == clN:
            
            ax.scatter(
                X[n, 0], X[n, 1],
                label=f'Cluster-{clN}, Tap-Score {score}',
                s=s, color=col, alpha=.8,
                marker=clMarkers[clN],
            )

    # if y_clust_labels[n] == 0:
    #     ax.scatter(
    #         X[n, 0], X[n, 1],
    #         label=f'Cluster-0, Tap-Score {score}',
    #         # edgecolor=col, facecolor='w',
    #         s=s, color=col, marker='*',
    #     )
    
    # elif y_clust_labels[n] == 1:
    #     ax.scatter(
    #         X[n, 0], X[n, 1], marker='+',
    #         label=f'Cluster-1, Tap-Score {score}',
    #         color=col, s=s, alpha=.7,
    #     )

    # elif y_clust_labels[n] == 2:
    #     ax.scatter(
    #         X[n, 0], X[n, 1],
    #         label=f'Cluster-2, Tap-Score {score}',
    #         color=col, s=s, alpha=.7,
    #     )

for c in range(centroids.shape[0]):
    ax.scatter(
        centroids[c, 0], centroids[c, 1],
        edgecolor='k', s=s + 50, fc='w',
        label='Cluster centers'
    )

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
ax.legend(
    by_label.values(), by_label.keys(),
    frameon=False, fontsize=16,
    ncol=1,
    loc='upper left',
    bbox_to_anchor=[1.01, .95]
)

ax.set_xlabel('PCA-1', fontsize=18)
ax.set_ylabel('PCA-2', fontsize=18)
ax.set_title(
    'kMeans Clustering 10-seconds of Finger Tapping',
    fontsize=20
)

# plt.savefig(
#     os.path.join(
#         fig_dir,
#         f'kMeans_{n_clusters}clusts_1AX_20220727'),
#     dpi=150, facecolor='w',
# )

plt.show()

# plt.hist(labels0, color='purple')
# plt.hist(labels1, color='green')

# %% [markdown]
# ### 3c. Classification

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import multilabel_confusion_matrix

# %% [markdown]
# #### Classifying UPDRS 0 - 1 - 2 - 3 - 4

# %%
# CLassification Settings
nFolds = 4

# Shuffle order
X = Xdf.values

allData = np.hstack((X, y))
X_shf = allData[:, :14]
y_shf = allData[:, 14]
np.random.seed(27)
np.random.shuffle(allData)

skf = StratifiedKFold(n_splits=nFolds,)
skf.get_n_splits(X_shf, y_shf)

y_pred, y_true = {}, {}

for F, (train_index, test_index) in enumerate(
    skf.split(X, y)
):
    print(f'Linear Support Vector, fold #{F}')

    X_train, X_test = X_shf[train_index], X_shf[test_index]
    y_train, y_test = y_shf[train_index], y_shf[test_index]

    clf = LinearSVC(penalty='l2', C=1.0,)
    clf.fit(X=X_train, y=y_train)
    print(clf.score(X=X_test, y=y_test))
    # for own scoring
    y_pred[F] = clf.predict(X=X_test)
    y_true[F] = y_test
    # print(multilabel_confusion_matrix(y_true[F], y_pred[F]))
# Out:
# Linear Support Vector, fold #0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7d/4ptht2m910d1y872jrgp9cq40000gp/T/ipykernel_10037/4282525040.py in <module>
#      25
#      26     clf = LinearSVC(penalty='l2', C=1.0,)
# ---> 27     clf.fit(X=X_train, y=y_train)
#      28     print(clf.score(X=X_test, y=y_test))
#      29     # for own scoring
#
# ~/anaconda3/envs/ecog_dysk/lib/python3.9/site-packages/sklearn/svm/_classes.py in fit(self, X, y, sample_weight)
#     252             accept_large_sparse=False,
#     253         )
# --> 254         check_classification_targets(y)
#     255         self.classes_ = np.unique(y)
#     256
#
# ~/anaconda3/envs/ecog_dysk/lib/python3.9/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     196         "multilabel-sequences",
#     197     ]:
# --> 198         raise ValueError("Unknown label type: %r" % y_type)
#     199
#     200
#
# ValueError: Unknown label type: 'continuous'

# %% [markdown]
# #### Boolean Classifying (UPDRS 0 or 4 vs The Rest)

# %%
# CLassification Settings
nFolds = 4
score_to_predict = 0

# Shuffle order
X = Xdf.values
y_bool = y == score_to_predict

allData = np.hstack((X, y_bool))

np.random.seed(27)
np.random.shuffle(allData)

X_shf = allData[:, :14]
y_shf = allData[:, 14]

skf = StratifiedKFold(n_splits=nFolds,)
skf.get_n_splits(X_shf, y_shf)

y_pred, y_true = {}, {}
print(
    'Classification of UPDRS subscore '
    f'{score_to_predict} versus thre rest')
for F, (train_index, test_index) in enumerate(
    skf.split(X, y)
):
    print(f'\nLinear Support Vector, fold #{F}')

    X_train, X_test = X_shf[train_index], X_shf[test_index]
    y_train, y_test = y_shf[train_index], y_shf[test_index]

    clf = LinearSVC(penalty='l2', C=1.0,)
    clf.fit(X=X_train, y=y_train)
    print(f'Accuracy: {clf.score(X=X_test, y=y_test)}')
    # for own scoring
    y_pred[F] = clf.predict(X=X_test)
    y_true[F] = y_test
    print(classification_report(y_true[F], y_pred[F]))
# Out:
# Classification of UPDRS subscore 0 versus thre rest
#
# Linear Support Vector, fold #0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7d/4ptht2m910d1y872jrgp9cq40000gp/T/ipykernel_10037/2107056001.py in <module>
#      31
#      32     clf = LinearSVC(penalty='l2', C=1.0,)
# ---> 33     clf.fit(X=X_train, y=y_train)
#      34     print(f'Accuracy: {clf.score(X=X_test, y=y_test)}')
#      35     # for own scoring
#
# ~/anaconda3/envs/ecog_dysk/lib/python3.9/site-packages/sklearn/svm/_classes.py in fit(self, X, y, sample_weight)
#     252             accept_large_sparse=False,
#     253         )
# --> 254         check_classification_targets(y)
#     255         self.classes_ = np.unique(y)
#     256
#
# ~/anaconda3/envs/ecog_dysk/lib/python3.9/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     196         "multilabel-sequences",
#     197     ]:
# --> 198         raise ValueError("Unknown label type: %r" % y_type)
#     199
#     200
#
# ValueError: Unknown label type: 'continuous'
